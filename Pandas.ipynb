# %% [markdown]
# # What is Pandas?

# %% [markdown]
# Pandas is a High level data manipulation tool built on the NumPy package.
#
# It is the most popular Python library for data analysis.
#
# This tool is essentially your data’s home.
#
# It's basically a way to store tabular data where you can label the rows and the columns.
#
# Through pandas, you get acquainted with your data by cleaning, transforming, and analyzing it.

# %% [markdown]
# ## import the pandas package
# To use pandas, you'll typically start with the following line of code.

# %%
import pandas as pd

# %% [markdown]
# ## Creating data
# There are two core objects in pandas: the DataFrame and the Series.

# %% [markdown]
# ### DataFrame
# A DataFrame is a table.
#
# It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row (or record) and a column.
#
# A dataframe can be created in the following ways:
# 1. Manually from a dictionary
# 2. By importing data from an external file, normally a '.csv(comma separated Values) file' that contains all the data.
#
# For example, consider the following simple DataFrame:

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %% [markdown]
# In this example, the "0, No" entry has the value of 131. The "0, Yes" entry has a value of 50, and so on.
#
# DataFrame entries are not limited to integers. For instance, here's a DataFrame whose values are strings:

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %% [markdown]
# We are using the pd.DataFrame() constructor to generate these DataFrame objects. The syntax for declaring a new one is a dictionary whose keys are the column names (Bob and Sue in this example), and whose values are a list of entries. This is the standard way of constructing a new DataFrame, and the one you are most likely to encounter.
#
# The dictionary-list constructor assigns values to the column labels, but just uses an ascending count from 0 (0, 1, 2, 3, ...) for the row labels. Sometimes this is OK, but oftentimes we will want to assign these labels ourselves.
#
# The list of row labels used in a DataFrame is known as an Index. We can assign values to it by using an index parameter in our constructor:

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# ### Series
# A Series, by contrast, is a sequence of data values.
#
# If a DataFrame is a table, a Series is a list. And in fact you can create one with nothing more than a list.
#
# A Series is, in essence, a single column of a DataFrame.

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# So you can assign column values to the Series the same way as before, using an index parameter.
#
# However, a Series does not have a column name, it only has one overall name:

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [markdown]
# The Series and the DataFrame are intimately related.
#
# It's helpful to think of a DataFrame as actually being just a bunch of Series "glued together".

# %%
# Creating a dataframe from a dictionary
East_Africa = {
    "Country" : ['Kenya', 'Uganda', 'Tanzania'],
    "Capital" : ['Nairobi', 'Kampala', 'Daressaalam'],
    "Area" : [205, 189, 250],
    "Population" : [49, 32, 50]
}

# %%
East_Africa
# Out:
# {'Country': ['Kenya', 'Uganda', 'Tanzania'],
#  'Capital': ['Nairobi', 'Kampala', 'Daressaalam'],
#  'Area': [205, 189, 250],
#  'Population': [49, 32, 50]}

# %%
East_Africa_df = pd.DataFrame(East_Africa)

# %%
East_Africa_df
# Out:
#     Country      Capital  Area  Population
# 0     Kenya      Nairobi   205          49
# 1    Uganda      Kampala   189          32
# 2  Tanzania  Daressaalam   250          50

# %% [markdown]
# ## Reading data

# %%
#Creating a dataframe by importing a .csv or a .json etc
financial_df = pd.read_csv('financialinclusion.csv')
financial_df
# Out:
#       country  year       uniqueid bank_account location_type  \
# 0       Kenya  2018     uniqueid_1          Yes         Rural
# 1       Kenya  2018     uniqueid_2           No         Rural
# 2       Kenya  2018     uniqueid_3          Yes         Urban
# 3       Kenya  2018     uniqueid_4           No         Rural
# 4       Kenya  2018     uniqueid_5           No         Urban
# 5       Kenya  2018     uniqueid_6           No         Rural
# 6       Kenya  2018     uniqueid_7           No         Rural
# 7       Kenya  2018     uniqueid_8           No         Rural
# 8       Kenya  2018     uniqueid_9          Yes         Rural
# 9       Kenya  2018    uniqueid_10           No         Urban
# 10      Kenya  2018    uniqueid_11           No         Rural
# 11      Kenya  2018    uniqueid_12          Yes         Rural
# 12      Kenya  2018    uniqueid_13           No         Rural
# 13      Kenya  2018    uniqueid_14           No         Rural
# 14      Kenya  2018    uniqueid_15           No         Urban
# 15      Kenya  2018    uniqueid_16           No         Rural
# 16      Kenya  2018    uniqueid_17           No         Urban
# 17      Kenya  2018    uniqueid_18          Yes         Rural
# 18      Kenya  2018    uniqueid_19           No         Urban
# 19      Kenya  2018    uniqueid_20           No         Rural
# 20      Kenya  2018    uniqueid_21           No         Rural
# 21      Kenya  2018    uniqueid_22          Yes         Urban
# 22      Kenya  2018    uniqueid_23           No         Urban
# 23      Kenya  2018    uniqueid_24           No         Rural
# 24      Kenya  2018    uniqueid_25           No         Urban
# 25      Kenya  2018    uniqueid_26           No         Rural
# 26      Kenya  2018    uniqueid_27           No         Rural
# 27      Kenya  2018    uniqueid_28           No         Urban
# 28      Kenya  2018    uniqueid_29           No         Rural
# 29      Kenya  2018    uniqueid_30           No         Rural
# ...       ...   ...            ...          ...           ...
# 23494  Uganda  2018  uniqueid_2082           No         Urban
# 23495  Uganda  2018  uniqueid_2083           No         Urban
# 23496  Uganda  2018  uniqueid_2084           No         Rural
# 23497  Uganda  2018  uniqueid_2085           No         Urban
# 23498  Uganda  2018  uniqueid_2086           No         Rural
# 23499  Uganda  2018  uniqueid_2087           No         Urban
# 23500  Uganda  2018  uniqueid_2088           No         Urban
# 23501  Uganda  2018  uniqueid_2089           No         Rural
# 23502  Uganda  2018  uniqueid_2090           No         Urban
# 23503  Uganda  2018  uniqueid_2091           No         Rural
# 23504  Uganda  2018  uniqueid_2093           No         Urban
# 23505  Uganda  2018  uniqueid_2095           No         Rural
# 23506  Uganda  2018  uniqueid_2096           No         Rural
# 23507  Uganda  2018  uniqueid_2097           No         Rural
# 23508  Uganda  2018  uniqueid_2098           No         Rural
# 23509  Uganda  2018  uniqueid_2099           No         Rural
# 23510  Uganda  2018  uniqueid_2100           No         Rural
# 23511  Uganda  2018  uniqueid_2101           No         Rural
# 23512  Uganda  2018  uniqueid_2102           No         Rural
# 23513  Uganda  2018  uniqueid_2103           No         Urban
# 23514  Uganda  2018  uniqueid_2107           No         Urban
# 23515  Uganda  2018  uniqueid_2108           No         Rural
# 23516  Uganda  2018  uniqueid_2109           No         Urban
# 23517  Uganda  2018  uniqueid_2110           No         Urban
# 23518  Uganda  2018  uniqueid_2111           No         Rural
# 23519  Uganda  2018  uniqueid_2113           No         Rural
# 23520  Uganda  2018  uniqueid_2114           No         Rural
# 23521  Uganda  2018  uniqueid_2115           No         Rural
# 23522  Uganda  2018  uniqueid_2116           No         Urban
# 23523  Uganda  2018  uniqueid_2117           No         Rural
#
#       cellphone_access  household_size  age_of_respondent  \
# 0                  Yes               3                 24
# 1                   No               5                 70
# 2                  Yes               5                 26
# 3                  Yes               5                 34
# 4                   No               8                 26
# 5                   No               7                 26
# 6                  Yes               7                 32
# 7                  Yes               1                 42
# 8                  Yes               3                 54
# 9                  Yes               3                 76
# 10                 Yes               5                 40
# 11                 Yes               3                 69
# 12                  No               6                 64
# 13                  No               8                 31
# 14                 Yes               4                 26
# 15                 Yes               7                 38
# 16                 Yes               1                 47
# 17                 Yes               6                 27
# 18                 Yes               1                 48
# 19                  No               4                 25
# 20                 Yes               4                 26
# 21                 Yes               1                 32
# 22                 Yes               4                 34
# 23                 Yes               3                 21
# 24                  No               7                 18
# 25                 Yes               5                 22
# 26                  No               8                 26
# 27                 Yes               1                 31
# 28                 Yes               4                 26
# 29                  No               7                 58
# ...                ...             ...                ...
# 23494              Yes               2                 25
# 23495               No               9                 21
# 23496               No               1                 60
# 23497               No               1                 74
# 23498              Yes               6                 26
# 23499               No               6                 16
# 23500               No               6                 26
# 23501               No               3                 22
# 23502              Yes               3                 17
# 23503               No               3                 40
# 23504              Yes               3                 24
# 23505              Yes               7                 45
# 23506               No               7                 22
# 23507               No               8                 28
# 23508              Yes               6                 65
# 23509               No               4                 20
# 23510              Yes               4                 30
# 23511               No               6                 19
# 23512               No               2                 57
# 23513              Yes               7                 26
# 23514              Yes               6                 24
# 23515               No               6                 16
# 23516              Yes               3                 35
# 23517              Yes               9                 16
# 23518              Yes               9                 20
# 23519              Yes               4                 48
# 23520              Yes               2                 27
# 23521              Yes               5                 27
# 23522              Yes               7                 30
# 23523              Yes              10                 20
#
#       gender_of_respondent relationship_with_head           marital_status  \
# 0                   Female                 Spouse  Married/Living together
# 1                   Female      Head of Household                  Widowed
# 2                     Male         Other relative     Single/Never Married
# 3                   Female      Head of Household  Married/Living together
# 4                     Male                  Child     Single/Never Married
# 5                   Female                 Spouse  Married/Living together
# 6                   Female                 Spouse  Married/Living together
# 7                   Female      Head of Household  Married/Living together
# 8                     Male      Head of Household  Married/Living together
# 9                   Female      Head of Household       Divorced/Seperated
# 10                  Female      Head of Household  Married/Living together
# 11                    Male      Head of Household  Married/Living together
# 12                  Female      Head of Household                  Widowed
# 13                  Female                 Spouse  Married/Living together
# 14                    Male      Head of Household  Married/Living together
# 15                    Male      Head of Household  Married/Living together
# 16                  Female      Head of Household  Married/Living together
# 17                  Female      Head of Household  Married/Living together
# 18                  Female      Head of Household     Single/Never Married
# 19                  Female                 Spouse  Married/Living together
# 20                    Male      Head of Household  Married/Living together
# 21                    Male      Head of Household     Single/Never Married
# 22                  Female                 Spouse  Married/Living together
# 23                  Female                 Spouse  Married/Living together
# 24                    Male         Other relative     Single/Never Married
# 25                  Female                  Child     Single/Never Married
# 26                    Male                  Child  Married/Living together
# 27                  Female      Head of Household     Single/Never Married
# 28                    Male      Head of Household  Married/Living together
# 29                  Female      Head of Household                  Widowed
# ...                    ...                    ...                      ...
# 23494               Female                 Spouse  Married/Living together
# 23495               Female      Head of Household  Married/Living together
# 23496               Female      Head of Household                  Widowed
# 23497               Female      Head of Household                  Widowed
# 23498                 Male      Head of Household  Married/Living together
# 23499               Female                 Parent     Single/Never Married
# 23500               Female                 Spouse  Married/Living together
# 23501               Female                 Spouse  Married/Living together
# 23502               Female                 Parent     Single/Never Married
# 23503               Female      Head of Household       Divorced/Seperated
# 23504               Female                 Spouse  Married/Living together
# 23505                 Male      Head of Household  Married/Living together
# 23506                 Male                  Child     Single/Never Married
# 23507               Female      Head of Household  Married/Living together
# 23508               Female      Head of Household                  Widowed
# 23509               Female                 Spouse  Married/Living together
# 23510               Female                 Spouse  Married/Living together
# 23511               Female                 Parent     Single/Never Married
# 23512               Female      Head of Household       Divorced/Seperated
# 23513               Female      Head of Household  Married/Living together
# 23514               Female                 Spouse  Married/Living together
# 23515                 Male                 Parent     Single/Never Married
# 23516                 Male      Head of Household  Married/Living together
# 23517                 Male                 Parent     Single/Never Married
# 23518               Female                  Child     Single/Never Married
# 23519               Female      Head of Household       Divorced/Seperated
# 23520               Female      Head of Household     Single/Never Married
# 23521               Female                 Parent                  Widowed
# 23522               Female                 Parent       Divorced/Seperated
# 23523                 Male                  Child     Single/Never Married
#
#                        education_level                      job_type
# 0                  Secondary education                 Self employed
# 1                  No formal education          Government Dependent
# 2      Vocational/Specialised training                 Self employed
# 3                    Primary education     Formally employed Private
# 4                    Primary education           Informally employed
# 5                    Primary education           Informally employed
# 6                    Primary education                 Self employed
# 7                   Tertiary education  Formally employed Government
# 8                  Secondary education           Farming and Fishing
# 9                  No formal education          Remittance Dependent
# 10                 Secondary education           Farming and Fishing
# 11                 Secondary education                  Other Income
# 12                 No formal education           Farming and Fishing
# 13                   Primary education                 Self employed
# 14                   Primary education           Informally employed
# 15                   Primary education           Informally employed
# 16                 Secondary education                 Self employed
# 17                 Secondary education                 Self employed
# 18     Vocational/Specialised training     Formally employed Private
# 19                   Primary education           Farming and Fishing
# 20                   Primary education           Farming and Fishing
# 21     Vocational/Specialised training                 Self employed
# 22                 Secondary education                 Self employed
# 23                 Secondary education           Informally employed
# 24                 Secondary education          Remittance Dependent
# 25                 Secondary education          Remittance Dependent
# 26                   Primary education                 Self employed
# 27                   Primary education           Informally employed
# 28                   Primary education     Formally employed Private
# 29                 No formal education          Remittance Dependent
# ...                                ...                           ...
# 23494              Secondary education                  Other Income
# 23495                Primary education                 Self employed
# 23496              No formal education                     No Income
# 23497              Secondary education                  Other Income
# 23498              Secondary education                 Self employed
# 23499              Secondary education                     No Income
# 23500                Primary education                     No Income
# 23501              Secondary education                 Self employed
# 23502  Vocational/Specialised training                  Other Income
# 23503                Primary education                 Self employed
# 23504  Vocational/Specialised training                     No Income
# 23505                Primary education                 Self employed
# 23506                Primary education                 Self employed
# 23507                Primary education                 Self employed
# 23508                Primary education                 Self employed
# 23509                Primary education                  Other Income
# 23510              No formal education                  Other Income
# 23511              Secondary education                     No Income
# 23512              No formal education                  Other Income
# 23513              Secondary education                     No Income
# 23514                Primary education                 Self employed
# 23515                Primary education                  Other Income
# 23516                Primary education                 Self employed
# 23517                Primary education                  Other Income
# 23518                Primary education                     No Income
# 23519              No formal education                  Other Income
# 23520              Secondary education                  Other Income
# 23521                Primary education                  Other Income
# 23522              Secondary education                 Self employed
# 23523              Secondary education                     No Income
#
# [23524 rows x 13 columns]

# %% [markdown]
# read_csv takes a number of optional arguments eg,
# * index_col
# * skiprows
# * header
# * usecols
# * skiprows
# * header
# * usecols
# * head()
# * tail()
# * describe()
# * count()
# * info()
# * shape
# * columns

# %%
# index_col
#Creating a dataframe by importing a .csv or a .json etc
financial_df = pd.read_csv('financialinclusion.csv', index_col = 2)
financial_df
# Out:
#               country  year bank_account location_type cellphone_access  \
# uniqueid
# uniqueid_1      Kenya  2018          Yes         Rural              Yes
# uniqueid_2      Kenya  2018           No         Rural               No
# uniqueid_3      Kenya  2018          Yes         Urban              Yes
# uniqueid_4      Kenya  2018           No         Rural              Yes
# uniqueid_5      Kenya  2018           No         Urban               No
# uniqueid_6      Kenya  2018           No         Rural               No
# uniqueid_7      Kenya  2018           No         Rural              Yes
# uniqueid_8      Kenya  2018           No         Rural              Yes
# uniqueid_9      Kenya  2018          Yes         Rural              Yes
# uniqueid_10     Kenya  2018           No         Urban              Yes
# uniqueid_11     Kenya  2018           No         Rural              Yes
# uniqueid_12     Kenya  2018          Yes         Rural              Yes
# uniqueid_13     Kenya  2018           No         Rural               No
# uniqueid_14     Kenya  2018           No         Rural               No
# uniqueid_15     Kenya  2018           No         Urban              Yes
# uniqueid_16     Kenya  2018           No         Rural              Yes
# uniqueid_17     Kenya  2018           No         Urban              Yes
# uniqueid_18     Kenya  2018          Yes         Rural              Yes
# uniqueid_19     Kenya  2018           No         Urban              Yes
# uniqueid_20     Kenya  2018           No         Rural               No
# uniqueid_21     Kenya  2018           No         Rural              Yes
# uniqueid_22     Kenya  2018          Yes         Urban              Yes
# uniqueid_23     Kenya  2018           No         Urban              Yes
# uniqueid_24     Kenya  2018           No         Rural              Yes
# uniqueid_25     Kenya  2018           No         Urban               No
# uniqueid_26     Kenya  2018           No         Rural              Yes
# uniqueid_27     Kenya  2018           No         Rural               No
# uniqueid_28     Kenya  2018           No         Urban              Yes
# uniqueid_29     Kenya  2018           No         Rural              Yes
# uniqueid_30     Kenya  2018           No         Rural               No
# uniqueid_2113              No formal education                  Other Income
# uniqueid_2114              Secondary education                  Other Income
# uniqueid_2115                Primary education                  Other Income
# uniqueid_2116              Secondary education                 Self employed
# uniqueid_2117              Secondary education                     No Income
#
# [23524 rows x 12 columns]

# %% [markdown]
# ## Try it yourself :-)

# %% [markdown]
# Use the pre-defined lists below to create a dictionary called my_dict.
#
# There should be three key value pairs:
#
# - key 'country' and value country_names.
#
# - key 'D_R' and value drives_right.
#
# - key 'C_P_C' and value cars_per_cap.

# %%
# Pre-defined lists
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
drives_right =  [True, False, False, False, True, True, True]
cars_per_cap = [809, 731, 588, 18, 200, 70, 45]

# %%
my_dict = {"country" : names, "D_R" : drives_right, "C_P_C" : cars_per_cap}
my_dict
# Out:
# {'country': ['United States',
#   'Australia',
#   'Japan',
#   'India',
#   'Russia',
#   'Morocco',
#   'Egypt'],
#  'D_R': [True, False, False, False, True, True, True],
#  'C_P_C': [809, 731, 588, 18, 200, 70, 45]}

# %% [markdown]
# Use pd.DataFrame() to turn your dict into a DataFrame called cars.
#
# Print out cars and see how beautiful it is.

# %%
cars = pd.DataFrame(my_dict)
cars
# Out:
#          country    D_R  C_P_C
# 0  United States   True    809
# 1      Australia  False    731
# 2          Japan  False    588
# 3          India  False     18
# 4         Russia   True    200
# 5        Morocco   True     70
# 6          Egypt   True     45

# %% [markdown]
# Notice that the row labels (i.e. the labels for the different observations) were automatically set to integers from 0 up to 6?
# To specify your own index values use .index method as below

# %%
# Definition of row_labels
row_labels = ['US', 'AUS', 'JPN', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index = row_labels

# Print cars again
cars
# Out:
#            country    D_R  C_P_C
# US   United States   True    809
# AUS      Australia  False    731
# JPN          Japan  False    588
# IN           India  False     18
# RU          Russia   True    200
# MOR        Morocco   True     70
# EG           Egypt   True     45

# %% [markdown]
# ### Selecting specific series(columns) of a DataFrame

# %% [markdown]
# #### Naive Accessors
# **dot(.)**

# %%
financial_df.country
# Out:
# uniqueid
# uniqueid_1        Kenya
# uniqueid_2        Kenya
# uniqueid_3        Kenya
# uniqueid_4        Kenya
# uniqueid_5        Kenya
# uniqueid_6        Kenya
# uniqueid_7        Kenya
# uniqueid_8        Kenya
# uniqueid_9        Kenya
# uniqueid_10       Kenya
# uniqueid_11       Kenya
# uniqueid_12       Kenya
# uniqueid_13       Kenya
# uniqueid_14       Kenya
# uniqueid_15       Kenya
# uniqueid_16       Kenya
# uniqueid_17       Kenya
# uniqueid_18       Kenya
# uniqueid_19       Kenya
# uniqueid_20       Kenya
# uniqueid_21       Kenya
# uniqueid_22       Kenya
# uniqueid_23       Kenya
# uniqueid_24       Kenya
# uniqueid_25       Kenya
# uniqueid_26       Kenya
# uniqueid_27       Kenya
# uniqueid_28       Kenya
# uniqueid_29       Kenya
# uniqueid_30       Kenya
#                   ...
# uniqueid_2082    Uganda
# uniqueid_2083    Uganda
# uniqueid_2084    Uganda
# uniqueid_2085    Uganda
# uniqueid_2086    Uganda
# uniqueid_2087    Uganda
# uniqueid_2088    Uganda
# uniqueid_2089    Uganda
# uniqueid_2090    Uganda
# uniqueid_2091    Uganda
# uniqueid_2093    Uganda
# uniqueid_2095    Uganda
# uniqueid_2096    Uganda
# uniqueid_2097    Uganda
# uniqueid_2098    Uganda
# uniqueid_2099    Uganda
# uniqueid_2100    Uganda
# uniqueid_2101    Uganda
# uniqueid_2102    Uganda
# uniqueid_2103    Uganda
# uniqueid_2107    Uganda
# uniqueid_2108    Uganda
# uniqueid_2109    Uganda
# uniqueid_2110    Uganda
# uniqueid_2111    Uganda
# uniqueid_2113    Uganda
# uniqueid_2114    Uganda
# uniqueid_2115    Uganda
# uniqueid_2116    Uganda
# uniqueid_2117    Uganda
# Name: country, Length: 23524, dtype: object

# %%
type(financial_df.country)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Square brackets method**
#
# Column access with square brackets.

# %%
financial_df["country"]
# Out:
# uniqueid
# uniqueid_1        Kenya
# uniqueid_2        Kenya
# uniqueid_3        Kenya
# uniqueid_4        Kenya
# uniqueid_5        Kenya
# uniqueid_6        Kenya
# uniqueid_7        Kenya
# uniqueid_8        Kenya
# uniqueid_9        Kenya
# uniqueid_10       Kenya
# uniqueid_11       Kenya
# uniqueid_12       Kenya
# uniqueid_13       Kenya
# uniqueid_14       Kenya
# uniqueid_15       Kenya
# uniqueid_16       Kenya
# uniqueid_17       Kenya
# uniqueid_18       Kenya
# uniqueid_19       Kenya
# uniqueid_20       Kenya
# uniqueid_21       Kenya
# uniqueid_22       Kenya
# uniqueid_23       Kenya
# uniqueid_24       Kenya
# uniqueid_25       Kenya
# uniqueid_26       Kenya
# uniqueid_27       Kenya
# uniqueid_28       Kenya
# uniqueid_29       Kenya
# uniqueid_30       Kenya
#                   ...
# uniqueid_2082    Uganda
# uniqueid_2083    Uganda
# uniqueid_2084    Uganda
# uniqueid_2085    Uganda
# uniqueid_2086    Uganda
# uniqueid_2087    Uganda
# uniqueid_2088    Uganda
# uniqueid_2089    Uganda
# uniqueid_2090    Uganda
# uniqueid_2091    Uganda
# uniqueid_2093    Uganda
# uniqueid_2095    Uganda
# uniqueid_2096    Uganda
# uniqueid_2097    Uganda
# uniqueid_2098    Uganda
# uniqueid_2099    Uganda
# uniqueid_2100    Uganda
# uniqueid_2101    Uganda
# uniqueid_2102    Uganda
# uniqueid_2103    Uganda
# uniqueid_2107    Uganda
# uniqueid_2108    Uganda
# uniqueid_2109    Uganda
# uniqueid_2110    Uganda
# uniqueid_2111    Uganda
# uniqueid_2113    Uganda
# uniqueid_2114    Uganda
# uniqueid_2115    Uganda
# uniqueid_2116    Uganda
# uniqueid_2117    Uganda
# Name: country, Length: 23524, dtype: object

# %%
type(financial_df["country"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Doesn't a pandas Series look kind of like a fancy list?
#
# It pretty much is, so it's no surprise that, to drill down to a single specific value, we need only use the indexing operator [] once more:

# %%
financial_df["country"][0]
# Out:
# 'Kenya'

# %%
type(financial_df["country"][0])
# Out:
# str

# %%
# using double square brackets results into a dataframe
financial_df[["country"]]
# Out:
#               country
# uniqueid
# uniqueid_1      Kenya
# uniqueid_2      Kenya
# uniqueid_3      Kenya
# uniqueid_4      Kenya
# uniqueid_5      Kenya
# uniqueid_6      Kenya
# uniqueid_7      Kenya
# uniqueid_8      Kenya
# uniqueid_9      Kenya
# uniqueid_10     Kenya
# uniqueid_11     Kenya
# uniqueid_12     Kenya
# uniqueid_13     Kenya
# uniqueid_14     Kenya
# uniqueid_15     Kenya
# uniqueid_16     Kenya
# uniqueid_17     Kenya
# uniqueid_18     Kenya
# uniqueid_19     Kenya
# uniqueid_20     Kenya
# uniqueid_21     Kenya
# uniqueid_22     Kenya
# uniqueid_23     Kenya
# uniqueid_24     Kenya
# uniqueid_25     Kenya
# uniqueid_26     Kenya
# uniqueid_27     Kenya
# uniqueid_28     Kenya
# uniqueid_29     Kenya
# uniqueid_30     Kenya
# ...               ...
# uniqueid_2082  Uganda
# uniqueid_2083  Uganda
# uniqueid_2084  Uganda
# uniqueid_2085  Uganda
# uniqueid_2086  Uganda
# uniqueid_2087  Uganda
# uniqueid_2088  Uganda
# uniqueid_2089  Uganda
# uniqueid_2090  Uganda
# uniqueid_2091  Uganda
# uniqueid_2093  Uganda
# uniqueid_2095  Uganda
# uniqueid_2096  Uganda
# uniqueid_2097  Uganda
# uniqueid_2098  Uganda
# uniqueid_2099  Uganda
# uniqueid_2100  Uganda
# uniqueid_2101  Uganda
# uniqueid_2102  Uganda
# uniqueid_2103  Uganda
# uniqueid_2107  Uganda
# uniqueid_2108  Uganda
# uniqueid_2109  Uganda
# uniqueid_2110  Uganda
# uniqueid_2111  Uganda
# uniqueid_2113  Uganda
# uniqueid_2114  Uganda
# uniqueid_2115  Uganda
# uniqueid_2116  Uganda
# uniqueid_2117  Uganda
#
# [23524 rows x 1 columns]

# %%
type(financial_df[["country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_df = pd.read_csv('titanic.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# row access with square brackets
titanic_df[0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# On its own, the : operator, which also comes from native Python, means "everything".

# %%
titanic_df[:]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 5        0            330877    8.4583          NaN        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 17       0            244373   13.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 26       0              2631    7.2250          NaN        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792          NaN        Q
# 29       0            349216    7.8958          NaN        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic_df.loc[:, ['Survived', 'Sex', 'Fare', 'Parch']]
# Out:
#      Survived     Sex      Fare  Parch
# 0           0    male    7.2500      0
# 1           1  female   71.2833      0
# 2           1  female    7.9250      0
# 3           1  female   53.1000      0
# 4           0    male    8.0500      0
# 5           0    male    8.4583      0
# 6           0    male   51.8625      0
# 7           0    male   21.0750      1
# 8           1  female   11.1333      2
# 9           1  female   30.0708      0
# 10          1  female   16.7000      1
# 11          1  female   26.5500      0
# 12          0    male    8.0500      0
# 13          0    male   31.2750      5
# 14          0  female    7.8542      0
# 15          1  female   16.0000      0
# 16          0    male   29.1250      1
# 17          1    male   13.0000      0
# 18          0  female   18.0000      0
# 19          1  female    7.2250      0
# 20          0    male   26.0000      0
# 21          1    male   13.0000      0
# 22          1  female    8.0292      0
# 23          1    male   35.5000      0
# 24          0  female   21.0750      1
# 25          1  female   31.3875      5
# 26          0    male    7.2250      0
# 27          0    male  263.0000      2
# 28          1  female    7.8792      0
# 29          0    male    7.8958      0
# ..        ...     ...       ...    ...
# 861         0    male   11.5000      0
# 862         1  female   25.9292      0
# 863         0  female   69.5500      2
# 864         0    male   13.0000      0
# 865         1  female   13.0000      0
# 866         1  female   13.8583      0
# 867         0    male   50.4958      0
# 868         0    male    9.5000      0
# 869         1    male   11.1333      1
# 870         0    male    7.8958      0
# 871         1  female   52.5542      1
# 872         0    male    5.0000      0
# 873         0    male    9.0000      0
# 874         1  female   24.0000      0
# 875         1  female    7.2250      0
# 876         0    male    9.8458      0
# 877         0    male    7.8958      0
# 878         0    male    7.8958      0
# 879         1  female   83.1583      1
# 880         1  female   26.0000      1
# 881         0    male    7.8958      0
# 882         0  female   10.5167      0
# 883         0    male   10.5000      0
# 884         0    male    7.0500      0
# 885         0  female   29.1250      5
# 886         0    male   13.0000      0
# 887         1  female   30.0000      0
# 888         0  female   23.4500      2
# 889         1    male   30.0000      0
# 890         0    male    7.7500      0
#
# [891 rows x 4 columns]

# %% [markdown]
# #### saving dataframe into a csv

# %% [markdown]
# ## Indexing in pandas
# Attribute selection are nice because they work just like they do in the rest of the Python ecosystem.
#
# As a novice, this makes them easy to pick up and use.
#
# However, pandas has its own accessor operators, loc and iloc.
#
# For more advanced operations, these are the ones you're supposed to be using.
#
# Both loc and iloc are row-first, column-second. This is the opposite of what we do in native Python, which is column-first, row-second.
#
# This means that it's marginally easier to retrieve rows, and marginally harder to get retrieve columns.

# %% [markdown]
# ### Index-based selection
# Selecting data based on its numerical position in the data.
#
# When we use iloc we treat the dataset like a big matrix (a list of lists), one that we have to index into by position.
#
# To select the first row of data in a DataFrame, we may use the following:

# %%
titanic_df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
# row access with iloc (Selecting rows using the index)
titanic_df.iloc[[1, 5, 8]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 5            6         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                   Moran, Mr. James    male   NaN      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 5      0    330877   8.4583   NaN        Q
# 8      2    347742  11.1333   NaN        S

# %%
# rows and columns access with iloc (Selecting rows and columns using the index)
titanic_df.iloc[:, 3]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# 16                                  Rice, Master. Eugene
# 17                          Williams, Mr. Charles Eugene
# 18     Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19                               Masselmani, Mrs. Fatima
# 20                                  Fynney, Mr. Joseph J
# 21                                 Beesley, Mr. Lawrence
# 22                           McGowan, Miss. Anna "Annie"
# 23                          Sloper, Mr. William Thompson
# 24                         Palsson, Miss. Torborg Danira
# 25     Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 26                               Emir, Mr. Farred Chehab
# 27                        Fortune, Mr. Charles Alexander
# 28                         O'Dwyer, Miss. Ellen "Nellie"
# 29                                   Todoroff, Mr. Lalio
#                              ...
# 861                          Giles, Mr. Frederick Edward
# 862    Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 863                    Sage, Miss. Dorothy Edith "Dolly"
# 864                               Gill, Mr. John William
# 865                             Bystrom, Mrs. (Karolina)
# 866                         Duran y More, Miss. Asuncion
# 867                 Roebling, Mr. Washington Augustus II
# 868                          van Melkebeke, Mr. Philemon
# 869                      Johnson, Master. Harold Theodor
# 870                                    Balkic, Mr. Cerin
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872                             Carlsson, Mr. Frans Olof
# 873                          Vander Cruyssen, Mr. Victor
# 874                Abelson, Mrs. Samuel (Hannah Wizosky)
# 875                     Najib, Miss. Adele Kiamie "Jane"
# 876                        Gustafsson, Mr. Alfred Ossian
# 877                                 Petroff, Mr. Nedelio
# 878                                   Laleff, Mr. Kristo
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 881                                   Markun, Mr. Johann
# 882                         Dahlberg, Miss. Gerda Ulrika
# 883                        Banfield, Mr. Frederick James
# 884                               Sutehall, Mr. Henry Jr
# 885                 Rice, Mrs. William (Margaret Norton)
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic_df.iloc[:3, 3]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# Name: Name, dtype: object

# %%
titanic_df.iloc[1:3, 3]
# Out:
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# Name: Name, dtype: object

# %%
# It's also possible to pass a list
titanic_df.iloc[[0, 1, 2], 3]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# Name: Name, dtype: object

# %%
titanic_df.iloc[[1, 30, 69],[0, 5, 7]]
# Out:
#     PassengerId   Age  Parch
# 1             2  38.0      0
# 30           31  40.0      0
# 69           70  26.0      0

# %% [markdown]
# Finally, it's worth knowing that negative numbers can be used in selection.
#
# This will start counting forwards from the end of the values.
#
# So for example here are the last five elements of the dataset.

# %%
titanic_df.iloc[-5:]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### Label-based selection
# In this paradigm, it's the data index value, not its position, which matters.
#
# loc uses the information in the indices to do its work.
#
# Since your dataset usually has meaningful indices, it's usually easier to do things using loc instead.

# %%
# row access with loc (Selecting rows using the  labels/index values)
titanic_df.loc[[1]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %%
titanic_df.loc[[1, 3, 5]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S
# 5      0    330877   8.4583   NaN        Q

# %%
# get the first name entry in titanic
titanic_df.loc[0, 'Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
titanic_df.loc[[0, 2, 3, 4, 5],['PassengerId', 'Age', 'Parch']]
# Out:
#    PassengerId   Age  Parch
# 0            1  22.0      0
# 2            3  26.0      0
# 3            4  35.0      0
# 4            5  35.0      0
# 5            6   NaN      0

# %% [markdown]
# ## Writing data

# %%
# saving dataframe into a csv
East_Africa_df.to_csv('east.csv')
east_df = pd.read_csv('east.csv', index_col=["Country"])
east_df
# Out:
#           Unnamed: 0      Capital  Area  Population
# Country
# Kenya              0      Nairobi   205          49
# Uganda             1      Kampala   189          32
# Tanzania           2  Daressaalam   250          50

# %%
# Manupilating the index
# east_df.set_index("Country")
# east_df

# %%
# row access with loc (Selecting rows using the label)
east_df.loc[['Kenya']]
# Out:
#          Unnamed: 0  Capital  Area  Population
# Country
# Kenya             0  Nairobi   205          49

# %%
titanic_df.loc[:, ['Survived', 'Gender', 'Fare', 'Parch']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#      Survived  Gender      Fare  Parch
# 0           0     NaN    7.2500      0
# 1           1     NaN   71.2833      0
# 2           1     NaN    7.9250      0
# 3           1     NaN   53.1000      0
# 4           0     NaN    8.0500      0
# 5           0     NaN    8.4583      0
# 6           0     NaN   51.8625      0
# 7           0     NaN   21.0750      1
# 8           1     NaN   11.1333      2
# 9           1     NaN   30.0708      0
# 10          1     NaN   16.7000      1
# 11          1     NaN   26.5500      0
# 12          0     NaN    8.0500      0
# 13          0     NaN   31.2750      5
# 14          0     NaN    7.8542      0
# 15          1     NaN   16.0000      0
# 16          0     NaN   29.1250      1
# 17          1     NaN   13.0000      0
# 18          0     NaN   18.0000      0
# 19          1     NaN    7.2250      0
# 20          0     NaN   26.0000      0
# 21          1     NaN   13.0000      0
# 22          1     NaN    8.0292      0
# 23          1     NaN   35.5000      0
# 24          0     NaN   21.0750      1
# 25          1     NaN   31.3875      5
# 26          0     NaN    7.2250      0
# 27          0     NaN  263.0000      2
# 28          1     NaN    7.8792      0
# 29          0     NaN    7.8958      0
# ..        ...     ...       ...    ...
# 861         0     NaN   11.5000      0
# 862         1     NaN   25.9292      0
# 863         0     NaN   69.5500      2
# 864         0     NaN   13.0000      0
# 865         1     NaN   13.0000      0
# 866         1     NaN   13.8583      0
# 867         0     NaN   50.4958      0
# 868         0     NaN    9.5000      0
# 869         1     NaN   11.1333      1
# 870         0     NaN    7.8958      0
# 871         1     NaN   52.5542      1
# 872         0     NaN    5.0000      0
# 873         0     NaN    9.0000      0
# 874         1     NaN   24.0000      0
# 875         1     NaN    7.2250      0
# 876         0     NaN    9.8458      0
# 877         0     NaN    7.8958      0
# 878         0     NaN    7.8958      0
# 879         1     NaN   83.1583      1
# 880         1     NaN   26.0000      1
# 881         0     NaN    7.8958      0
# 882         0     NaN   10.5167      0
# 883         0     NaN   10.5000      0
# 884         0     NaN    7.0500      0
# 885         0     NaN   29.1250      5
# 886         0     NaN   13.0000      0
# 887         1     NaN   30.0000      0
# 888         0     NaN   23.4500      2
# 889         1     NaN   30.0000      0
# 890         0     NaN    7.7500      0
#
# [891 rows x 4 columns]

# %%
# combining square brackets with loc and iloc
titanic_df[['Survived', 'Sex', 'Fare', 'Parch']].loc[:]
# Out:
#      Survived     Sex      Fare  Parch
# 0           0    male    7.2500      0
# 1           1  female   71.2833      0
# 2           1  female    7.9250      0
# 3           1  female   53.1000      0
# 4           0    male    8.0500      0
# 5           0    male    8.4583      0
# 6           0    male   51.8625      0
# 7           0    male   21.0750      1
# 8           1  female   11.1333      2
# 9           1  female   30.0708      0
# 10          1  female   16.7000      1
# 11          1  female   26.5500      0
# 12          0    male    8.0500      0
# 13          0    male   31.2750      5
# 14          0  female    7.8542      0
# 15          1  female   16.0000      0
# 16          0    male   29.1250      1
# 17          1    male   13.0000      0
# 18          0  female   18.0000      0
# 19          1  female    7.2250      0
# 20          0    male   26.0000      0
# 21          1    male   13.0000      0
# 22          1  female    8.0292      0
# 23          1    male   35.5000      0
# 24          0  female   21.0750      1
# 25          1  female   31.3875      5
# 26          0    male    7.2250      0
# 27          0    male  263.0000      2
# 28          1  female    7.8792      0
# 29          0    male    7.8958      0
# ..        ...     ...       ...    ...
# 861         0    male   11.5000      0
# 862         1  female   25.9292      0
# 863         0  female   69.5500      2
# 864         0    male   13.0000      0
# 865         1  female   13.0000      0
# 866         1  female   13.8583      0
# 867         0    male   50.4958      0
# 868         0    male    9.5000      0
# 869         1    male   11.1333      1
# 870         0    male    7.8958      0
# 871         1  female   52.5542      1
# 872         0    male    5.0000      0
# 873         0    male    9.0000      0
# 874         1  female   24.0000      0
# 875         1  female    7.2250      0
# 876         0    male    9.8458      0
# 877         0    male    7.8958      0
# 878         0    male    7.8958      0
# 879         1  female   83.1583      1
# 880         1  female   26.0000      1
# 881         0    male    7.8958      0
# 882         0  female   10.5167      0
# 883         0    male   10.5000      0
# 884         0    male    7.0500      0
# 885         0  female   29.1250      5
# 886         0    male   13.0000      0
# 887         1  female   30.0000      0
# 888         0  female   23.4500      2
# 889         1    male   30.0000      0
# 890         0    male    7.7500      0
#
# [891 rows x 4 columns]

# %% [markdown]
# iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded.
#
# So 0:10 will select entries 0,...,9.
#
# loc, meanwhile, indexes inclusively.
#
# So 0:10 will select entries 0,...,10.

# %% [markdown]
# ### Selection of data
# So far we've been indexing various strides of data, using structural properties of the DataFrame itself.
#
# To do interesting things with the data, however, we often need to ask questions based on conditions.
#
# The aim is to select relevant data out of a DataFrame or Series.

# %%
titanic_df[titanic_df['Sex']=='female'].head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
titanic_df.loc[titanic_df['Sex'] == 'female'].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
titanic_df[titanic_df['Sex']=='male'].iloc[:10]
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 5             6         0       3                Moran, Mr. James  male   NaN
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7             8         0       3  Palsson, Master. Gosta Leonard  male   2.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
# 13           14         0       3     Andersson, Mr. Anders Johan  male  39.0
# 16           17         0       3            Rice, Master. Eugene  male   2.0
# 17           18         1       2    Williams, Mr. Charles Eugene  male   NaN
# 20           21         0       2            Fynney, Mr. Joseph J  male  35.0
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked
# 0       1      0  A/5 21171   7.2500   NaN        S
# 4       0      0     373450   8.0500   NaN        S
# 5       0      0     330877   8.4583   NaN        Q
# 6       0      0      17463  51.8625   E46        S
# 7       3      1     349909  21.0750   NaN        S
# 12      0      0  A/5. 2151   8.0500   NaN        S
# 13      1      5     347082  31.2750   NaN        S
# 16      4      1     382652  29.1250   NaN        Q
# 17      0      0     244373  13.0000   NaN        S
# 20      0      0     239865  26.0000   NaN        S

# %%
titanic_df.loc[titanic_df['Sex'] == 'male'].head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         0       3        Allen, Mr. William Henry  male  35.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
titanic_df[(titanic_df['Name']=='Icard, Miss. Amelie')]
# Out:
#     PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 61           62         1       1  Icard, Miss. Amelie  female  38.0      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 61      0  113572  80.0   B28      NaN

# %%
titanic_df.loc[(titanic_df['Name']=='Icard, Miss. Amelie')]
# Out:
#     PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 61           62         1       1  Icard, Miss. Amelie  female  38.0      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 61      0  113572  80.0   B28      NaN

# %%
titanic_df[(titanic_df['Name']=='Icard, Miss. Amelie')].loc[:, ['Name']]
# Out:
#                    Name
# 61  Icard, Miss. Amelie

# %%
titanic_df.loc[(titanic_df['Name']=='Icard, Miss. Amelie')].loc[:, ['Name']]
# Out:
#                    Name
# 61  Icard, Miss. Amelie

# %%
titanic_df[titanic_df['Age']<40].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.loc[titanic_df['Age']<40].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Logical operators

# %% [markdown]
# #### and
# We can use the ampersand (&) to bring the two questions together:

# %%
titanic_df.loc[(titanic_df['Age']>=30) & (titanic_df['Sex']=='female')].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 11           12         1       1
# 15           16         1       2
# 18           19         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 11      0    113783  26.5500  C103        S
# 15      0    248706  16.0000   NaN        S
# 18      0    345763  18.0000   NaN        S

# %% [markdown]
# #### or

# %%
titanic_df.loc[(titanic_df['Age']<25) | (titanic_df['Sex']=="female")].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 7      1            349909  21.0750   NaN        S

# %% [markdown]
# #### Combining logical operators

# %%
titanic_df[((titanic_df['Age']<30) | (titanic_df['Age']>40))&(titanic_df['Sex']=='male')].loc[:10,['Name', 'Age', 'Sex']]
# Out:
#                              Name   Age   Sex
# 0         Braund, Mr. Owen Harris  22.0  male
# 6         McCarthy, Mr. Timothy J  54.0  male
# 7  Palsson, Master. Gosta Leonard   2.0  male

# %% [markdown]
# ### Built-in conditional selectors

# %% [markdown]
# #### isin
# isin is lets you select data whose value "is in" a list of values.

# %%
titanic_df.loc[titanic_df['PassengerId'].isin([1, 2, 3])]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# #### isnull / notnull
# These methods let you highlight values which are (or are not) empty (NaN).

# %%
titanic_df.loc[titanic_df['Age'].isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %% [markdown]
# ### Assigning data
# You can assign either with a constant value or an iterable of values.

# %%
# assigning a constant
east_df['Constant'] = 'constant'
east_df
# Out:
#           Unnamed: 0      Capital  Area  Population  Constant
# Country
# Kenya              0      Nairobi   205          49  constant
# Uganda             1      Kampala   189          32  constant
# Tanzania           2  Daressaalam   250          50  constant

# %%
# assigning an iterable of values
east_df['Iterable'] = ['Iterable1', 'Iterable2', 'Iterable3']
east_df
# Out:
#           Unnamed: 0      Capital  Area  Population  Constant   Iterable
# Country
# Kenya              0      Nairobi   205          49  constant  Iterable1
# Uganda             1      Kampala   189          32  constant  Iterable2
# Tanzania           2  Daressaalam   250          50  constant  Iterable3

# %% [markdown]
# # Using Pandas for some Exploratory Data Analysis

# %% [markdown]
# Plucking the right data out of our data representation is critical to getting work done.
#
# However, the data does not always come out of memory in the format we want it in right out of the bat. Sometimes we have to do some more work ourselves to reformat it for the task at hand.

# %% [markdown]
# ### Viewing your data
# The first thing to do when opening a new dataset is print out a few rows to keep as a visual reference.
#
# **.head()** is used to achieve this.
#
# It takes in an integer parameter to specify number of rows to be displayed.

# %%
#using the financial_df dataframe created above
financial_df.head()
# Out:
#            country  year bank_account location_type cellphone_access  \
# uniqueid
# uniqueid_1   Kenya  2018          Yes         Rural              Yes
# uniqueid_2   Kenya  2018           No         Rural               No
# uniqueid_3   Kenya  2018          Yes         Urban              Yes
# uniqueid_4   Kenya  2018           No         Rural              Yes
# uniqueid_5   Kenya  2018           No         Urban               No
#
#             household_size  age_of_respondent gender_of_respondent  \
# uniqueid
# uniqueid_1               3                 24               Female
# uniqueid_2               5                 70               Female
# uniqueid_3               5                 26                 Male
# uniqueid_4               5                 34               Female
# uniqueid_5               8                 26                 Male
#
#            relationship_with_head           marital_status  \
# uniqueid
# uniqueid_1                 Spouse  Married/Living together
# uniqueid_2      Head of Household                  Widowed
# uniqueid_3         Other relative     Single/Never Married
# uniqueid_4      Head of Household  Married/Living together
# uniqueid_5                  Child     Single/Never Married
#
#                             education_level                   job_type
# uniqueid
# uniqueid_1              Secondary education              Self employed
# uniqueid_2              No formal education       Government Dependent
# uniqueid_3  Vocational/Specialised training              Self employed
# uniqueid_4                Primary education  Formally employed Private
# uniqueid_5                Primary education        Informally employed

# %% [markdown]
# To see the last five rows use **.tail()**.
#
# It takes in an integer parameter to specify number of rows to be displayed.

# %%
financial_df.tail()
# Out:
#               country  year bank_account location_type cellphone_access  \
# uniqueid
# uniqueid_2113  Uganda  2018           No         Rural              Yes
# uniqueid_2114  Uganda  2018           No         Rural              Yes
# uniqueid_2115  Uganda  2018           No         Rural              Yes
# uniqueid_2116  Uganda  2018           No         Urban              Yes
# uniqueid_2117  Uganda  2018           No         Rural              Yes
#
#                household_size  age_of_respondent gender_of_respondent  \
# uniqueid
# uniqueid_2113               4                 48               Female
# uniqueid_2114               2                 27               Female
# uniqueid_2115               5                 27               Female
# uniqueid_2116               7                 30               Female
# uniqueid_2117              10                 20                 Male
#
#               relationship_with_head        marital_status  \
# uniqueid
# uniqueid_2113      Head of Household    Divorced/Seperated
# uniqueid_2114      Head of Household  Single/Never Married
# uniqueid_2115                 Parent               Widowed
# uniqueid_2116                 Parent    Divorced/Seperated
# uniqueid_2117                  Child  Single/Never Married
#
#                    education_level       job_type
# uniqueid
# uniqueid_2113  No formal education   Other Income
# uniqueid_2114  Secondary education   Other Income
# uniqueid_2115    Primary education   Other Income
# uniqueid_2116  Secondary education  Self employed
# uniqueid_2117  Secondary education      No Income

# %% [markdown]
# ### Summary functions
#  "summary functions" (not an official name) restructure the data in some useful way.

# %% [markdown]
# **.describe()**
#
# This method generates a high-level summary of the attributes of the given column.
#
# It is type-aware, meaning that its output changes based on the data type of the input.

# %%
financial_df['year'].describe()
# Out:
# count    23524.000000
# mean      2016.975939
# std          0.847371
# min       2016.000000
# 25%       2016.000000
# 50%       2017.000000
# 75%       2018.000000
# max       2018.000000
# Name: year, dtype: float64

# %%
financial_df.describe()
# Out:
#                year  household_size  age_of_respondent
# count  23524.000000    23524.000000       23524.000000
# mean    2016.975939        3.797483          38.805220
# std        0.847371        2.227613          16.520569
# min     2016.000000        1.000000          16.000000
# 25%     2016.000000        2.000000          26.000000
# 50%     2017.000000        3.000000          35.000000
# 75%     2018.000000        5.000000          49.000000
# max     2018.000000       21.000000         100.000000

# %% [markdown]
# **.info()**

# %%
financial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23524 entries, uniqueid_1 to uniqueid_2117
# Data columns (total 12 columns):
# country                   23524 non-null object
# year                      23524 non-null int64
# bank_account              23524 non-null object
# location_type             23524 non-null object
# cellphone_access          23524 non-null object
# household_size            23524 non-null int64
# age_of_respondent         23524 non-null int64
# gender_of_respondent      23524 non-null object
# relationship_with_head    23524 non-null object
# marital_status            23524 non-null object
# education_level           23524 non-null object
# job_type                  23524 non-null object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB

# %% [markdown]
# Object == string
#
# int64 == int
#
# float64 == float
#
# datetime64
#
# Seeing the datatype quickly is actually quite useful. Imagine you just imported some JSON/CSV and the integers were recorded as strings. You go to do some arithmetic and find an "unsupported operand" Exception because you can't do math with strings. Calling .info() will quickly point out that your column you thought was all integers are actually string objects.

# %% [markdown]
# **.shape**
#
# Outputs just a tuple of (rows, columns):

# %%
financial_df.shape
# Out:
# (23524, 12)

# %% [markdown]
# **.columns**
#
# Many times datasets will have verbose column names with symbols, upper and lowercase words, spaces, and typos. To make selecting data by column name easier we can spend a little time cleaning up their names.
#
# Here's how to print the column names of our dataset:

# %%
financial_df.columns
# Out:
# Index(['country', 'year', 'bank_account', 'location_type', 'cellphone_access',
#        'household_size', 'age_of_respondent', 'gender_of_respondent',
#        'relationship_with_head', 'marital_status', 'education_level',
#        'job_type'],
#       dtype='object')

# %% [markdown]
# **.rename()**
#
# We can use the .rename() method to rename certain or all columns via a dictionary:

# %%
financial_df.rename(columns={
        'uniqueid': 'UniqueID', 
        'gender_of_respondent': 'RespondentsGender'
    }, inplace=True)

# %%
financial_df.columns
# Out:
# Index(['country', 'year', 'bank_account', 'location_type', 'cellphone_access',
#        'household_size', 'age_of_respondent', 'RespondentsGender',
#        'relationship_with_head', 'marital_status', 'education_level',
#        'job_type'],
#       dtype='object')

# %% [markdown]
# **.unique()**
#
# To see a list of unique values we can use the unique() function:

# %%
financial_df['country'].unique()
# Out:
# array(['Kenya', 'Rwanda', 'Tanzania', 'Uganda'], dtype=object)

# %% [markdown]
# **.value_counts()**
#
# To see a list of unique values and how often they occur in the dataset, we can use the value_counts() method:

# %%
financial_df['country'].value_counts()
# Out:
# Rwanda      8735
# Tanzania    6620
# Kenya       6068
# Uganda      2101
# Name: country, dtype: int64

# %% [markdown]
# ### Maps
# A map is a term, borrowed from mathematics, for a function that takes one set of values and "maps" them to another set of values.
#
# In data science we often have a need for creating new representations from existing data, or for transforming data from the format it is in now to the format that we want it to be in later.
#
# There are two mapping methods that you will use often: **map()** and **apply()**

# %% [markdown]
# **1. map()**
#
# The function you pass to map() should expect a single value from the Series (a point value, in the above example), and return a transformed version of that value. map() returns a new Series where all the values have been transformed by your function.

# %%
# minus current household_size values from the household_size mean
financial_df_householdsize_mean = financial_df['household_size'].mean()
financial_df['household_size'].map(lambda p: p - financial_df_householdsize_mean)
# Out:
# uniqueid
# uniqueid_1      -0.797483
# uniqueid_2       1.202517
# uniqueid_3       1.202517
# uniqueid_4       1.202517
# uniqueid_5       4.202517
# uniqueid_6       3.202517
# uniqueid_7       3.202517
# uniqueid_8      -2.797483
# uniqueid_9      -0.797483
# uniqueid_10     -0.797483
# uniqueid_11      1.202517
# uniqueid_12     -0.797483
# uniqueid_13      2.202517
# uniqueid_14      4.202517
# uniqueid_15      0.202517
# uniqueid_16      3.202517
# uniqueid_17     -2.797483
# uniqueid_18      2.202517
# uniqueid_19     -2.797483
# uniqueid_2098                Primary education                 Self employed
# uniqueid_2099                Primary education                  Other Income
# uniqueid_2100              No formal education                  Other Income
# uniqueid_2101              Secondary education                     No Income
# uniqueid_2102              No formal education                  Other Income
# uniqueid_2103              Secondary education                     No Income
# uniqueid_2107                Primary education                 Self employed
# uniqueid_2108                Primary education                  Other Income
# uniqueid_2109                Primary education                 Self employed
# uniqueid_2110                Primary education                  Other Income
# uniqueid_2111                Primary education                     No Income
# uniqueid_2113              No formal education                  Other Income
# uniqueid_2114              Secondary education                  Other Income
# uniqueid_2115                Primary education                  Other Income
# uniqueid_2116              Secondary education                 Self employed
# uniqueid_2117              Secondary education                     No Income
#
# [23524 rows x 12 columns]

# %% [markdown]
# If we had called reviews.apply() with axis='index', then instead of passing a function to transform each row, we would need to give a function to transform each column.
#
# **Note:**
# * **map()** and **apply()** return new, transformed Series and DataFrames, respectively. They don't modify the original data they're called on.

# %%
financial_df.head()
# Out:
#            country  year bank_account location_type cellphone_access  \
# uniqueid
# uniqueid_1   Kenya  2018          Yes         Rural              Yes
# uniqueid_2   Kenya  2018           No         Rural               No
# uniqueid_3   Kenya  2018          Yes         Urban              Yes
# uniqueid_4   Kenya  2018           No         Rural              Yes
# uniqueid_5   Kenya  2018           No         Urban               No
#
#             household_size  age_of_respondent RespondentsGender  \
# uniqueid
# uniqueid_1               3                 24            Female
# uniqueid_2               5                 70            Female
# uniqueid_3               5                 26              Male
# uniqueid_4               5                 34            Female
# uniqueid_5               8                 26              Male
#
#            relationship_with_head           marital_status  \
# uniqueid
# uniqueid_1                 Spouse  Married/Living together
# uniqueid_2      Head of Household                  Widowed
# uniqueid_3         Other relative     Single/Never Married
# uniqueid_4      Head of Household  Married/Living together
# uniqueid_5                  Child     Single/Never Married
#
#                             education_level                   job_type
# uniqueid
# uniqueid_1              Secondary education              Self employed
# uniqueid_2              No formal education       Government Dependent
# uniqueid_3  Vocational/Specialised training              Self employed
# uniqueid_4                Primary education  Formally employed Private
# uniqueid_5                Primary education        Informally employed

# %% [markdown]
# **Pandas provides many common mapping operations as built-ins. For example, here's a faster way of remeaning our points column:**

# %%
financial_df_householdsize_mean = financial_df.household_size.mean()
financial_df.household_size - financial_df_householdsize_mean
# Out:
# uniqueid
# uniqueid_1      -0.797483
# uniqueid_2       1.202517
# uniqueid_3       1.202517
# uniqueid_4       1.202517
# uniqueid_5       4.202517
# uniqueid_6       3.202517
# uniqueid_7       3.202517
# uniqueid_8      -2.797483
# uniqueid_9      -0.797483
# uniqueid_10     -0.797483
# uniqueid_11      1.202517
# uniqueid_12     -0.797483
# uniqueid_13      2.202517
# uniqueid_14      4.202517
# uniqueid_15      0.202517
# uniqueid_16      3.202517
# uniqueid_17     -2.797483
# uniqueid_18      2.202517
# uniqueid_19     -2.797483
# uniqueid_20      0.202517
# uniqueid_21      0.202517
# uniqueid_22     -2.797483
# uniqueid_23      0.202517
# uniqueid_24     -0.797483
# uniqueid_25      3.202517
# uniqueid_26      1.202517
# uniqueid_27      4.202517
# uniqueid_28     -2.797483
# uniqueid_2099                     Primary education - Other Income
# uniqueid_2100                   No formal education - Other Income
# uniqueid_2101                      Secondary education - No Income
# uniqueid_2102                   No formal education - Other Income
# uniqueid_2103                      Secondary education - No Income
# uniqueid_2107                    Primary education - Self employed
# uniqueid_2108                     Primary education - Other Income
# uniqueid_2109                    Primary education - Self employed
# uniqueid_2110                     Primary education - Other Income
# uniqueid_2111                        Primary education - No Income
# uniqueid_2113                   No formal education - Other Income
# uniqueid_2114                   Secondary education - Other Income
# uniqueid_2115                     Primary education - Other Income
# uniqueid_2116                  Secondary education - Self employed
# uniqueid_2117                      Secondary education - No Income
# Length: 23524, dtype: object

# %% [markdown]
# These operators are faster than map() or apply() because they uses speed ups built into pandas.
#
# However, they are not as flexible as map() or apply(), which can do more advanced things, like applying conditional logic, which cannot be done with addition and subtraction alone.
#
# See [Kaggle's pandas: Summary Functions and Maps](https://www.kaggle.com/learn/pandas) for more examples.
#
# [Kaggle's pandas exercise on Summary Functions and Maps](https://www.kaggle.com/aubreyjohn/exercise-summary-functions-and-maps/edit)

# %% [markdown]
# ## Groupwise Analysis
# Often we want to group our data, and then do something specific to the group the data is in.
#
# You can think of each group we generate as being a slice of our DataFrame containing only data with values that match.

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# group by
titanic_df_sex = titanic_df.groupby('Sex')
titanic_df_sex

# %%
titanic_df_sex['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
titanic_df_survived = titanic_df.groupby('Survived')
titanic_df_survived['Fare'].mean()
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64

# %%
titanic_df_survived['Age'].median()
# Out:
# Survived
# 0    28.0
# 1    28.0
# Name: Age, dtype: float64

# %%
financial_df.head()
# Out:
#            country  year bank_account location_type cellphone_access  \
# uniqueid
# uniqueid_1   Kenya  2018          Yes         Rural              Yes
# uniqueid_2   Kenya  2018           No         Rural               No
# uniqueid_3   Kenya  2018          Yes         Urban              Yes
# uniqueid_4   Kenya  2018           No         Rural              Yes
# uniqueid_5   Kenya  2018           No         Urban               No
#
#             household_size  age_of_respondent RespondentsGender  \
# uniqueid
# uniqueid_1               3                 24            Female
# uniqueid_2               5                 70            Female
# uniqueid_3               5                 26              Male
# uniqueid_4               5                 34            Female
# uniqueid_5               8                 26              Male
#
#            relationship_with_head           marital_status  \
# uniqueid
# uniqueid_1                 Spouse  Married/Living together
# uniqueid_2      Head of Household                  Widowed
# uniqueid_3         Other relative     Single/Never Married
# uniqueid_4      Head of Household  Married/Living together
# uniqueid_5                  Child     Single/Never Married
#
#                             education_level                   job_type
# uniqueid
# uniqueid_1              Secondary education              Self employed
# uniqueid_2              No formal education       Government Dependent
# uniqueid_3  Vocational/Specialised training              Self employed
# uniqueid_4                Primary education  Formally employed Private
# uniqueid_5                Primary education        Informally employed

# %%
# value_counts is a shorter way to achieve the result below
financial_df.groupby('country').country.count()
# Out:
# country
# Kenya       6068
# Rwanda      8735
# Tanzania    6620
# Uganda      2101
# Name: country, dtype: int64

# %%
financial_df['country'].value_counts()
# Out:
# Rwanda      8735
# Tanzania    6620
# Kenya       6068
# Uganda      2101
# Name: country, dtype: int64

# %%
financial_df.groupby('country').size()
# Out:
# country
# Kenya       6068
# Rwanda      8735
# Tanzania    6620
# Uganda      2101
# dtype: int64

# %%
# we can use summary functions together with groupby 
financial_df.groupby('country').household_size.max()
# Out:
# country
# Kenya       21
# Rwanda      13
# Tanzania    14
# Uganda      20
# Name: household_size, dtype: int64

# %% [markdown]
# Each group (a slice of our DataFrame) contains only data with values that match.
#
# This DataFrame is accessible to us directly using the **apply()** method, and we can then manipulate the data in any way we see fit.

# %%
financial_df.groupby('location_type').apply(lambda df: df.job_type.iloc[0])
# Out:
# location_type
# Rural    Self employed
# Urban    Self employed
# dtype: object

# %% [markdown]
# For even more fine-grained control, you can also group by more than one column.

# %%
titanic_df_survived['Age', 'Fare'].mean()
# Out:
#                 Age       Fare
# Survived
# 0         30.626179  22.117887
# 1         28.343690  48.395408

# %%
titanic_df_sex['Age', 'Fare'].mean()
# Out:
#               Age       Fare
# Sex
# female  27.915709  44.479818
# male    30.726645  25.523893

# %%
financial_df.groupby(['country','location_type']).household_size.max()
# Out:
# country   location_type
# Kenya     Rural            21
#           Urban            16
# Rwanda    Rural            13
#           Urban            13
# Tanzania  Rural            14
#           Urban            12
# Uganda    Rural            20
#           Urban            17
# Name: household_size, dtype: int64

# %%
financial_df.groupby(['country','location_type']).apply(lambda df: df.loc[df.household_size.idxmax()])
# Out:
#                          country  year bank_account location_type  \
# country  location_type
# Kenya    Rural             Kenya  2018           No         Rural
#          Urban             Kenya  2018           No         Urban
# Rwanda   Rural            Rwanda  2016           No         Rural
#          Urban            Rwanda  2016           No         Urban
# Tanzania Rural          Tanzania  2017           No         Rural
#          Urban          Tanzania  2017           No         Urban
# Uganda   Rural            Uganda  2018           No         Rural
#          Urban            Uganda  2018          Yes         Urban
#
#                        cellphone_access  household_size  age_of_respondent  \
# country  location_type
# Kenya    Rural                       No              21                 59
#          Urban                      Yes              16                 33
# Rwanda   Rural                      Yes              13                 19
#          Urban                      Yes              13                 18
# Tanzania Rural                       No              14                 17
#          Urban                      Yes              12                 17
# Uganda   Rural                       No              20                 28
#          Urban                      Yes              17                 70
#
#                        RespondentsGender relationship_with_head  \
# country  location_type
# Kenya    Rural                    Female                 Spouse
#          Urban                    Female                 Spouse
# Rwanda   Rural                      Male                  Child
#          Urban                      Male                  Child
# Tanzania Rural                      Male    Other non-relatives
#          Urban                      Male                 Parent
# Uganda   Rural                    Female         Other relative
#          Urban                    Female      Head of Household
#
#                                  marital_status      education_level  \
# country  location_type
# Kenya    Rural          Married/Living together  No formal education
#          Urban          Married/Living together  No formal education
# Rwanda   Rural             Single/Never Married  Secondary education
#          Urban             Single/Never Married  Secondary education
# Tanzania Rural               Divorced/Seperated  Secondary education
#          Urban               Divorced/Seperated    Primary education
# Uganda   Rural          Married/Living together    Primary education
#          Urban                          Widowed    Primary education
#
#                                     job_type
# country  location_type
# Kenya    Rural          Remittance Dependent
#          Urban          Remittance Dependent
# Rwanda   Rural           Informally employed
#          Urban           Informally employed
# Tanzania Rural          Remittance Dependent
#          Urban                     No Income
# Uganda   Rural                     No Income
#          Urban                  Other Income

# %% [markdown]
# Another **groupby()** method worth mentioning is **agg()**, which lets you run a bunch of different functions on your DataFrame simultaneously.

# %%
financial_df.groupby('country').household_size.agg([len, min, max])
# Out:
#            len  min  max
# country
# Kenya     6068    1   21
# Rwanda    8735    1   13
# Tanzania  6620    1   14
# Uganda    2101    1   20

# %% [markdown]
# ## Multi-indexing
# groupby() is slightly different in the fact that, depending on the operation we run, it will sometimes result in what is called a **multi-index**.
#
# A **multi-index** differs from a **regular index** in that it has multiple levels.
#
# They require two levels of labels to retrieve a value.
#
# The use cases for a multi-index are detailed alongside instructions on using them in the [MultiIndex / Advanced Selection](https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html) section of the pandas documentation.

# %%
financial_multi = financial_df.groupby(['country','location_type']).household_size.max()
financial_multi_index = financial_multi.index
financial_multi_index
# Out:
# MultiIndex(levels=[['Kenya', 'Rwanda', 'Tanzania', 'Uganda'], ['Rural', 'Urban']],
#            codes=[[0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 0, 1, 0, 1, 0, 1]],
#            names=['country', 'location_type'])

# %% [markdown]
# Multi-index method you will use most often is the one for converting back to a regular index, the **reset_index()** method:

# %%
financial_multi.reset_index()
# Out:
#     country location_type  household_size
# 0     Kenya         Rural              21
# 1     Kenya         Urban              16
# 2    Rwanda         Rural              13
# 3    Rwanda         Urban              13
# 4  Tanzania         Rural              14
# 5  Tanzania         Urban              12
# 6    Uganda         Rural              20
# 7    Uganda         Urban              17

# %% [markdown]
# ## Sorting

# %% [markdown]
# When outputting the result of a groupby, the order of the rows is dependent on the values in the index, not in the data.
#
# To get data in the order want it in we can sort it ourselves. The **sort_values()** method is handy for this.

# %%
financial_multi_index_reset = financial_multi.reset_index()
financial_multi_index_reset.sort_values('household_size')
# Out:
#     country location_type  household_size
# 5  Tanzania         Urban              12
# 2    Rwanda         Rural              13
# 3    Rwanda         Urban              13
# 4  Tanzania         Rural              14
# 1     Kenya         Urban              16
# 7    Uganda         Urban              17
# 6    Uganda         Rural              20
# 0     Kenya         Rural              21

# %%
financial_multi_index_reset.sort_values(by = 'household_size')
# Out:
#     country location_type  household_size
# 5  Tanzania         Urban              12
# 2    Rwanda         Rural              13
# 3    Rwanda         Urban              13
# 4  Tanzania         Rural              14
# 1     Kenya         Urban              16
# 7    Uganda         Urban              17
# 6    Uganda         Rural              20
# 0     Kenya         Rural              21

# %% [markdown]
# **sort_values()** defaults to an **ascending sort**, where the lowest values go first. However, most of the time we want a **descending sort**, where the higher numbers go first. That goes thusly:

# %%
financial_multi_index_reset.sort_values(by = 'household_size', ascending = False)
# Out:
#     country location_type  household_size
# 0     Kenya         Rural              21
# 6    Uganda         Rural              20
# 7    Uganda         Urban              17
# 1     Kenya         Urban              16
# 4  Tanzania         Rural              14
# 2    Rwanda         Rural              13
# 3    Rwanda         Urban              13
# 5  Tanzania         Urban              12

# %% [markdown]
# To sort by index values, use the companion method **sort_index()**. This method has the same arguments and default order:

# %%
financial_multi_index_reset.sort_index()
# Out:
#     country location_type  household_size
# 0     Kenya         Rural              21
# 1     Kenya         Urban              16
# 2    Rwanda         Rural              13
# 3    Rwanda         Urban              13
# 4  Tanzania         Rural              14
# 5  Tanzania         Urban              12
# 6    Uganda         Rural              20
# 7    Uganda         Urban              17

# %% [markdown]
# You can sort by more than one column at a time:

# %%
financial_multi_index_reset.sort_values(by = ['country', 'household_size'])
# Out:
#     country location_type  household_size
# 1     Kenya         Urban              16
# 0     Kenya         Rural              21
# 2    Rwanda         Rural              13
# 3    Rwanda         Urban              13
# 5  Tanzania         Urban              12
# 4  Tanzania         Rural              14
# 7    Uganda         Urban              17
# 6    Uganda         Rural              20

# %%
financial_df.groupby(['country', 'location_type']).household_size.count()
# Out:
# country   location_type
# Kenya     Rural            3543
#           Urban            2525
# Rwanda    Rural            7483
#           Urban            1252
# Tanzania  Rural            1809
#           Urban            4811
# Uganda    Rural            1508
#           Urban             593
# Name: household_size, dtype: int64

# %%
financial_df.groupby(['country', 'location_type']).size()
# Out:
# country   location_type
# Kenya     Rural            3543
#           Urban            2525
# Rwanda    Rural            7483
#           Urban            1252
# Tanzania  Rural            1809
#           Urban            4811
# Uganda    Rural            1508
#           Urban             593
# dtype: int64

# %%
type(financial_df.groupby(['country', 'location_type']).size())
# Out:
# pandas.core.series.Series

# %%
financial_df.groupby(['country', 'location_type']).size().sort_values(ascending = False)
# Out:
# country   location_type
# Rwanda    Rural            7483
# Tanzania  Urban            4811
# Kenya     Rural            3543
#           Urban            2525
# Tanzania  Rural            1809
# Uganda    Rural            1508
# Rwanda    Urban            1252
# Uganda    Urban             593
# dtype: int64

# %% [markdown]
# ## Data Types
# The data type for a column in a DataFrame or a Series is known as the **dtype**.

# %%
financial_df['household_size'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# The dtypes property returns the dtype of every column in the DataFrame:

# %%
financial_df.dtypes
# Out:
# country                   object
# year                       int64
# bank_account              object
# location_type             object
# cellphone_access          object
# household_size             int64
# age_of_respondent          int64
# RespondentsGender         object
# relationship_with_head    object
# marital_status            object
# education_level           object
# job_type                  object
# dtype: object

# %% [markdown]
# Data types tell us something about how pandas is storing the data internally.
#
# float64 means that it's using a 64-bit floating point number.
#
# Columns consisting entirely of strings do not get their own type; they are instead given the object type.

# %% [markdown]
# It's possible to convert a column of one type into another wherever such a conversion makes sense by using the **astype()** function.

# %%
financial_df['age_of_respondent'].astype('float64').head()
# Out:
# uniqueid
# uniqueid_1    24.0
# uniqueid_2    70.0
# uniqueid_3    26.0
# uniqueid_4    34.0
# uniqueid_5    26.0
# Name: age_of_respondent, dtype: float64

# %% [markdown]
# A DataFrame or Series index has its own dtype

# %%
financial_df = financial_df.reset_index()
financial_df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Pandas also supports more exotic data types, such as categorical data and timeseries data.
#
# Because these data types are more rarely used, we will omit them until a much later.

# %% [markdown]
# ## Working with missing values
# When exploring data, you’ll most likely encounter missing or null values.
#
# Entries missing values are given the value NaN, short for "Not a Number". For technical reasons these NaN values are always of the float64 dtype.
#
# Most commonly you'll see Python's None or NumPy's np.nan, each of which are handled differently in some situations.

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Check existence of null values
# To check if NaN entries exist you can use **isnull()** (or its companion **notnull()**).

# %%
titanic_df.isnull().head()
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False
# 3  False  False     False
# 4  False   True     False

# %%
titanic_df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic_df.isnull().all()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Select Null Entries
# To select NaN entries you can use **pd.isnull()** (or its companion **pd.notnull()**).

# %%
titanic_df[pd.isnull(titanic_df.Age)]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# 121          122         0       3
# 126          127         0       3
# 128          129         1       3
# 140          141         0       3
# 154          155         0       3
# ..           ...       ...     ...
# 718          719         0       3
# 727          728         1       3
# 732          733         0       2
# 738          739         0       3
# 739          740         0       3
# 740          741         1       1
# 760          761         0       3
# 766          767         0       1
# 768          769         0       3
# 773          774         0       3
# 776          777         0       3
# 778          779         0       3
# 783          784         0       3
# 790          791         0       3
# 792          793         0       3
# 793          794         0       1
# 815          816         0       1
# 825          826         0       3
# 826          827         0       3
# 828          829         1       3
# 832          833         0       3
# 837          838         0       3
# 839          840         1       1
# 846          847         0       3
# 849          850         1       1
# 859          860         0       3
# 863          864         0       3
# 868          869         0       3
# 878          879         0       3
# 888          889         0       3
#
#                                                Name     Sex  Age  SibSp  \
# 5                                  Moran, Mr. James    male  NaN      0
# 17                     Williams, Mr. Charles Eugene    male  NaN      0
# 19                          Masselmani, Mrs. Fatima  female  NaN      0
# 26                          Emir, Mr. Farred Chehab    male  NaN      0
# 28                    O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0
# 29                              Todoroff, Mr. Lalio    male  NaN      0
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female  NaN      1
# 32                         Glynn, Miss. Mary Agatha  female  NaN      0
# 36                                 Mamee, Mr. Hanna    male  NaN      0
# 42                              Kraeff, Mr. Theodor    male  NaN      0
# 45                         Rogers, Mr. William John    male  NaN      0
# 46                                Lennon, Mr. Denis    male  NaN      1
# 47                        O'Driscoll, Miss. Bridget  female  NaN      0
# 46       0           370371   15.5000    NaN        Q
# 47       0            14311    7.7500    NaN        Q
# 48       0             2662   21.6792    NaN        C
# 55       0            19947   35.5000    C52        S
# 64       0         PC 17605   27.7208    NaN        C
# 65       1             2661   15.2458    NaN        C
# 76       0           349208    7.8958    NaN        S
# 77       0           374746    8.0500    NaN        S
# 82       0           330932    7.7875    NaN        Q
# 87       0  SOTON/OQ 392086    8.0500    NaN        S
# 95       0           374910    8.0500    NaN        S
# 101      0           349215    7.8958    NaN        S
# 107      0           312991    7.7750    NaN        S
# 109      0           371110   24.1500    NaN        Q
# 121      0        A4. 54510    8.0500    NaN        S
# 126      0           370372    7.7500    NaN        Q
# 128      1             2668   22.3583  F E69        C
# 140      2             2678   15.2458    NaN        C
# 154      0        Fa 265302    7.3125    NaN        S
# ..     ...              ...       ...    ...      ...
# 718      0            36568   15.5000    NaN        Q
# 727      0            36866    7.7375    NaN        Q
# 732      0           239855    0.0000    NaN        S
# 738      0           349201    7.8958    NaN        S
# 739      0           349218    7.8958    NaN        S
# 740      0            16988   30.0000    D45        S
# 760      0           358585   14.5000    NaN        S
# 766      0           112379   39.6000    NaN        C
# 768      0           371110   24.1500    NaN        Q
# 773      0             2674    7.2250    NaN        C
# 776      0           383121    7.7500    F38        Q
# 778      0            36865    7.7375    NaN        Q
# 783      2       W./C. 6607   23.4500    NaN        S
# 790      0            12460    7.7500    NaN        Q
# 792      2         CA. 2343   69.5500    NaN        S
# 793      0         PC 17600   30.6958    NaN        C
# 815      0           112058    0.0000   B102        S
# 825      0           368323    6.9500    NaN        Q
# 826      0             1601   56.4958    NaN        S
# 828      0           367228    7.7500    NaN        Q
# 832      0             2671    7.2292    NaN        C
# 837      0           392092    8.0500    NaN        S
# 839      0            11774   29.7000    C47        C
# 846      2         CA. 2343   69.5500    NaN        S
# 849      0            17453   89.1042    C92        C
# 859      0             2629    7.2292    NaN        C
# 863      2         CA. 2343   69.5500    NaN        S
# 868      0           345777    9.5000    NaN        S
# 878      0           349217    7.8958    NaN        S
# 888      2       W./C. 6607   23.4500    NaN        S
#
# [177 rows x 12 columns]

# %% [markdown]
# **There are various ways of dealing with nulls:**
#
# * Get rid of rows or columns with nulls.
# * Replace nulls with non-null values, a technique known as imputation.
# * We could fill each missing value with the first non-null value that appears sometime after the given record in the database. This is known as the backfill strategy.

# %% [markdown]
# ### Dropping missing values

# %%
titanic_missing = titanic_df.dropna(axis = 1)
titanic_missing.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %% [markdown]
# ### Replacing null values
# Replacing missing values is a common operation. Pandas provides a really handy method for this problem: **fillna()**.
#
# **fillna()** provides a few different strategies for mitigating such data.

# %%
titanic_null_unknown = titanic_df.Age.fillna("Unknown")
titanic_null_unknown.head(10)
# Out:
# 0         22
# 1         38
# 2         26
# 3         35
# 4         35
# 5    Unknown
# 6         54
# 7          2
# 8         27
# 9         14
# Name: Age, dtype: object

# %%
housing_df = pd.read_csv('housing.csv')
housing_df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %%
housing_df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# Length: 81, dtype: int64

# %%
housing_df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# FireplaceQu       object
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# GarageQual        object
# GarageCond        object
# PavedDrive        object
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# PoolQC            object
# Fence             object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# #### imputing missing values with mean

# %%
LotFrontage_mean = housing_df['LotFrontage'].mean()
LotFrontage_mean
# Out:
# 70.04995836802665

# %%
# replace LotFrontage null values with LotFrontage's mean
housing_df.LotFrontage.fillna(housing_df['LotFrontage'].mean(), inplace=True)
housing_df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL    65.000000     8450   Pave   NaN      Reg
# 1   2          20       RL    80.000000     9600   Pave   NaN      Reg
# 2   3          60       RL    68.000000    11250   Pave   NaN      IR1
# 3   4          70       RL    60.000000     9550   Pave   NaN      IR1
# 4   5          60       RL    84.000000    14260   Pave   NaN      IR1
# 5   6          50       RL    85.000000    14115   Pave   NaN      IR1
# 6   7          20       RL    75.000000    10084   Pave   NaN      Reg
# 7   8          60       RL    70.049958    10382   Pave   NaN      IR1
# 8   9          50       RM    51.000000     6120   Pave   NaN      Reg
# 9  10         190       RL    50.000000     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %% [markdown]
# #### imputing missing values with median

# %%
MoSold_median = housing_df['MoSold'].median()
MoSold_median
# Out:
# 6.0

# %%
#### replace MoSold null values with MoSold's median
housing_df.LotFrontage.fillna(housing_df['MoSold'].median(), inplace=True)
housing_df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL    65.000000     8450   Pave   NaN      Reg
# 1   2          20       RL    80.000000     9600   Pave   NaN      Reg
# 2   3          60       RL    68.000000    11250   Pave   NaN      IR1
# 3   4          70       RL    60.000000     9550   Pave   NaN      IR1
# 4   5          60       RL    84.000000    14260   Pave   NaN      IR1
# 5   6          50       RL    85.000000    14115   Pave   NaN      IR1
# 6   7          20       RL    75.000000    10084   Pave   NaN      Reg
# 7   8          60       RL    70.049958    10382   Pave   NaN      IR1
# 8   9          50       RM    51.000000     6120   Pave   NaN      Reg
# 9  10         190       RL    50.000000     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %% [markdown]
# #### imputing missing values with mode

# %%
#### imputing missing values with mode
GarageYrBlt_mode = housing_df['GarageYrBlt'].mode()
GarageYrBlt_mode
# Out:
# 0    2005.0
# dtype: float64

# %%
#### imputing missing values with median
housing_df.GarageYrBlt.fillna(housing_df['GarageYrBlt'].mode(), inplace=True)
housing_df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL    65.000000     8450   Pave   NaN      Reg
# 1   2          20       RL    80.000000     9600   Pave   NaN      Reg
# 2   3          60       RL    68.000000    11250   Pave   NaN      IR1
# 3   4          70       RL    60.000000     9550   Pave   NaN      IR1
# 4   5          60       RL    84.000000    14260   Pave   NaN      IR1
# 5   6          50       RL    85.000000    14115   Pave   NaN      IR1
# 6   7          20       RL    75.000000    10084   Pave   NaN      Reg
# 7   8          60       RL    70.049958    10382   Pave   NaN      IR1
# 8   9          50       RM    51.000000     6120   Pave   NaN      Reg
# 9  10         190       RL    50.000000     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %% [markdown]
# ### Replacing non-null values
# We may have a non-null value that we would like to replace.
#
# In that case, we use the **replace()** method.
#
# The replace() method is worth mentioning here because it's handy for replacing missing data which is given some kind of sentinel value in the dataset: things like "Unknown", "Undisclosed", "Invalid", and so on.

# %%
titanic_null_unknown_replace = titanic_null_unknown.replace('Unknown', 'Undisclosed')
titanic_null_unknown_replace.head(10)
# Out:
# 0             22
# 1             38
# 2             26
# 3             35
# 4             35
# 5    Undisclosed
# 6             54
# 7              2
# 8             27
# 9             14
# Name: Age, dtype: object

# %% [markdown]
# ## Renaming
# **rename()** lets you change index names and/or column names.

# %% [markdown]
# ### Renaming column names

# %%
housing_df.rename(columns = {
    'MoSold' : 'Month_Sold',
    'YrSold' : 'Year_Sold'
}, inplace = True)
housing_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#   Month_Sold Year_Sold  SaleType  SaleCondition  SalePrice
# 0          2      2008        WD         Normal     208500
# 1          5      2007        WD         Normal     181500
# 2          9      2008        WD         Normal     223500
# 3          2      2006        WD        Abnorml     140000
# 4         12      2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# When inplace=True is passed, the data is renamed in place (it returns nothing), so you'd use:
#
# df.an_operation(inplace=True)
#
# When inplace=False is passed (this is the default value, so isn't necessary), performs the operation and returns a copy of the object, so you'd use:
#
# df = df.an_operation(inplace=False)

# %% [markdown]
# ### Renaming index names

# %%
housing_df.rename(index={0: 'firstEntry', 1: 'secondEntry'}).head()
# Out:
#              Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# firstEntry    1          60       RL         65.0     8450   Pave   NaN
# secondEntry   2          20       RL         80.0     9600   Pave   NaN
# 2             3          60       RL         68.0    11250   Pave   NaN
# 3             4          70       RL         60.0     9550   Pave   NaN
# 4             5          60       RL         84.0    14260   Pave   NaN
#
#             LotShape LandContour Utilities  ... PoolArea PoolQC Fence  \
# firstEntry       Reg         Lvl    AllPub  ...        0    NaN   NaN
# secondEntry      Reg         Lvl    AllPub  ...        0    NaN   NaN
# 2                IR1         Lvl    AllPub  ...        0    NaN   NaN
# 3                IR1         Lvl    AllPub  ...        0    NaN   NaN
# 4                IR1         Lvl    AllPub  ...        0    NaN   NaN
#
#             MiscFeature MiscVal Month_Sold Year_Sold  SaleType  SaleCondition  \
# firstEntry          NaN       0          2      2008        WD         Normal
# secondEntry         NaN       0          5      2007        WD         Normal
# 2                   NaN       0          9      2008        WD         Normal
# 3                   NaN       0          2      2006        WD        Abnorml
# 4                   NaN       0         12      2008        WD         Normal
#
#              SalePrice
# firstEntry      208500
# secondEntry     181500
# 2               223500
# 3               140000
# 4               250000
#
# [5 rows x 81 columns]

# %% [markdown]
# You'll probably rename columns very often, but rename index values very rarely.
#
# For that, **set_index()** is usually more convenient.

# %% [markdown]
# Both the row index and the column index can have their own name attribute.
#
# The complimentary **rename_axis()** method may be used to change these names.

# %%
housing_df.rename_axis("houses", axis='rows').rename_axis("features", axis='columns').head()
# Out:
# features  Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# houses
# 0          1          60       RL         65.0     8450   Pave   NaN      Reg
# 1          2          20       RL         80.0     9600   Pave   NaN      Reg
# 2          3          60       RL         68.0    11250   Pave   NaN      IR1
# 3          4          70       RL         60.0     9550   Pave   NaN      IR1
# 4          5          60       RL         84.0    14260   Pave   NaN      IR1
#
# features LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# houses                          ...
# 0                Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1                Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 2                Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 3                Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 4                Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
# features Month_Sold Year_Sold  SaleType  SaleCondition  SalePrice
# houses
# 0                 2      2008        WD         Normal     208500
# 1                 5      2007        WD         Normal     181500
# 2                 9      2008        WD         Normal     223500
# 3                 2      2006        WD        Abnorml     140000
# 4                12      2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Combining
# We will sometimes need to combine different DataFrames and/or Series in non-trivial ways.
#
# Pandas has three core methods for doing this. In order of increasing complexity, these are:
# * concat()
# * join()
# * merge().

# %% [markdown]
# ### concat()
# Given a list of elements, this function will smush those elements together along an axis.
#
# This is useful when we have data in different DataFrame or Series objects but having the same fields (columns).

# %%
housing_df_concat = [housing_df.head(10),housing_df.tail(10)]
pd.concat(housing_df_concat)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL    65.000000     8450   Pave   NaN      Reg
# 1        2          20       RL    80.000000     9600   Pave   NaN      Reg
# 2        3          60       RL    68.000000    11250   Pave   NaN      IR1
# 3        4          70       RL    60.000000     9550   Pave   NaN      IR1
# 4        5          60       RL    84.000000    14260   Pave   NaN      IR1
# 5        6          50       RL    85.000000    14115   Pave   NaN      IR1
# 6        7          20       RL    75.000000    10084   Pave   NaN      Reg
# 7        8          60       RL    70.049958    10382   Pave   NaN      IR1
# 8        9          50       RM    51.000000     6120   Pave   NaN      Reg
# 9       10         190       RL    50.000000     7420   Pave   NaN      Reg
# 1450  1451          90       RL    60.000000     9000   Pave   NaN      Reg
# 1451  1452          20       RL    78.000000     9262   Pave   NaN      Reg
# 1452  1453         180       RM    35.000000     3675   Pave   NaN      Reg
# 1453  1454          20       RL    90.000000    17217   Pave   NaN      Reg
# 1454  1455          20       FV    62.000000     7500   Pave  Pave      Reg
# 1455  1456          60       RL    62.000000     7917   Pave   NaN      Reg
# 1456  1457          20       RL    85.000000    13175   Pave   NaN      Reg
# 1457  1458          70       RL    66.000000     9042   Pave   NaN      Reg
# 1458  1459          20       RL    68.000000     9717   Pave   NaN      Reg
# 1459  1460          20       RL    75.000000     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5            Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7            Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1450         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1451         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1452         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1453         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1454         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      Month_Sold Year_Sold  SaleType  SaleCondition  SalePrice
# 0             2      2008        WD         Normal     208500
# 1             5      2007        WD         Normal     181500
# 2             9      2008        WD         Normal     223500
# 3             2      2006        WD        Abnorml     140000
# 4            12      2008        WD         Normal     250000
# 5            10      2009        WD         Normal     143000
# 6             8      2007        WD         Normal     307000
# 7            11      2009        WD         Normal     200000
# 8             4      2008        WD        Abnorml     129900
# 9             1      2008        WD         Normal     118000
# 1450          9      2009        WD         Normal     136000
# 1451          5      2009       New        Partial     287090
# 1452          5      2006        WD         Normal     145000
# 1453          7      2006        WD        Abnorml      84500
# 1454         10      2009        WD         Normal     185000
# 1455          8      2007        WD         Normal     175000
# 1456          2      2010        WD         Normal     210000
# 1457          5      2010        WD         Normal     266500
# 1458          4      2010        WD         Normal     142125
# 1459          6      2008        WD         Normal     147500
#
# [20 rows x 81 columns]

# %% [markdown]
# ### join()
# **join()** lets you combine different DataFrame objects which have an index in common.

# %%
df1 = titanic_df.loc[[0,1,2,3,4,5],['PassengerId', 'Survived', 'Sex']]
df1
# Out:
#    PassengerId  Survived     Sex
# 0            1         0    male
# 1            2         1  female
# 2            3         1  female
# 3            4         1  female
# 4            5         0    male
# 5            6         0    male

# %%
df2 = titanic_df.loc[[0,2,5,7,8,10],['PassengerId', 'Age', 'Parch']]
df2
# Out:
#     PassengerId   Age  Parch
# 0             1  22.0      0
# 2             3  26.0      0
# 5             6   NaN      0
# 7             8   2.0      1
# 8             9  27.0      2
# 10           11   4.0      1

# %%
left = df1
right = df2

left.join(right, lsuffix='_left', rsuffix='_right')
# Out:
#    PassengerId_left  Survived     Sex  PassengerId_right   Age  Parch
# 0                 1         0    male                1.0  22.0    0.0
# 1                 2         1  female                NaN   NaN    NaN
# 2                 3         1  female                3.0  26.0    0.0
# 3                 4         1  female                NaN   NaN    NaN
# 4                 5         0    male                NaN   NaN    NaN
# 5                 6         0    male                6.0   NaN    0.0

# %% [markdown]
# The **lsuffix** and **rsuffix** parameters are necessary here because the data has the same column names in both left and right datasets.
#
# If this wasn't true (because, say, we'd renamed them beforehand) we wouldn't need them.

# %% [markdown]
# ### merge()

# %%
print("Inner - Natural Join")  # intersection - only those that appear in both datasets
pd.merge(df1, df2, on='PassengerId', how='inner')
# Out:
# Inner - Natural Join
#    PassengerId  Survived  Gender   Age  Parch
# 0            1         0     NaN  22.0      0
# 1            3         1     NaN  26.0      0
# 2            6         0     NaN   NaN      0

# %%
print("Outer - Full Outer Join")  # union - combination of everything in both datasets
pd.merge(df1, df2, on='PassengerId', how='outer')
# Out:
# Outer - Full Outer Join
#    PassengerId  Survived  Gender   Age  Parch
# 0            1       0.0     NaN  22.0    0.0
# 1            2       1.0     NaN   NaN    NaN
# 2            3       1.0     NaN  26.0    0.0
# 3            4       1.0     NaN   NaN    NaN
# 4            5       0.0     NaN   NaN    NaN
# 5            6       0.0     NaN   NaN    0.0
# 6            8       NaN     NaN   2.0    1.0
# 7            9       NaN     NaN  27.0    2.0
# 8           11       NaN     NaN   4.0    1.0

# %%
print("Left - Left Outer Join")
pd.merge(df1, df2, on='PassengerId', how='left')
# Out:
# Left - Left Outer Join
#    PassengerId  Survived  Gender   Age  Parch
# 0            1         0     NaN  22.0    0.0
# 1            2         1     NaN   NaN    NaN
# 2            3         1     NaN  26.0    0.0
# 3            4         1     NaN   NaN    NaN
# 4            5         0     NaN   NaN    NaN
# 5            6         0     NaN   NaN    0.0

# %%
print("Right - Right Outer Join")
pd.merge(df1, df2, on='PassengerId', how='right')
# Out:
# Right - Right Outer Join
#    PassengerId  Survived     Sex   Age  Parch
# 0            1       0.0    male  22.0      0
# 1            3       1.0  female  26.0      0
# 2            6       0.0    male   NaN      0
# 3            8       NaN     NaN   2.0      1
# 4            9       NaN     NaN  27.0      2
# 5           11       NaN     NaN   4.0      1
